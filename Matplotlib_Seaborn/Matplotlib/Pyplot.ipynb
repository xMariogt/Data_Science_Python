# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ![Numero1](cheatsheets-1.png)

# %% [markdown]
# ![Numero2](handout-beginner.png)

# %% [markdown]
# ![Numero3](handout-intermediate.png)

# %% [markdown]
# ![Numero4](cheatsheets-2.png)

# %% [markdown]
# ![Numero5](handout-tips.png)

# %%
x = np.linspace(0,5,11)

# %%
y = x**2

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y, 'yx')
plt.show()

# %%
plt.plot(x,y, 'r3')
plt.show()

# %%
plt.plot(x,y, '<:', color= 'green')
plt.show()

# %%
plt.hist(x)
plt.show()

# %%
plt.pie(y)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.boxplot(x, )
plt.show()
