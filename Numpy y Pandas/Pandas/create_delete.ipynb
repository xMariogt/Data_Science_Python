# %%
import pandas as pd
import numpy as np

# %%
books = pd.read_csv("C:/Users/Mario/Desktop/Data_Visualization/Numpy y Pandas/Pandas/bestsellers-with-categories_e591527f-ae45-4fa5-b0d1-d50142128fa6.csv", sep=',', header=0)
#Aqui se lee un archivo separado por comas y se asigna como el cabecero los datos en la posicion 0 del arreglo, con names= se puede asignar nombres a los cabeceros

# %%
books.head() #Muestra los primeros 5 registros de un dataframe
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
books.head(2)#Muestra los primeros 2 registros de un dataframe
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %% [markdown]
# # Drop Columns

# %%
books.drop('Genre', axis=1).head(2) #unicamente quita 'Genre' de la salida pero no lo elimina del dataframe
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year
# 0  2016
# 1  2011

# %%
books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %%
books.drop('Genre', axis=1,inplace=True) #Elimina la columna Genre de todo el dataframe

del books['Price'] #Tambien elimina toda una columna del dataframe

# %% [markdown]
# # Drop Rows

# %%
books.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Year
# 0                  JJ Smith          4.7    17350  2016
# 1              Stephen King          4.6     2052  2011
# 2        Jordan B. Peterson          4.7    18979  2018
# 3             George Orwell          4.7    21424  2017
# 4  National Geographic Kids          4.8     7665  2019

# %%
books.drop(1,axis=0).head(2)
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  Year
# 0    17350  2016
# 2    18979  2018

# %%
books.drop(range(0,10), axis=0).head()
# Out:
#                                                  Name             Author  \
# 10                          A Man Called Ove: A Novel    Fredrik Backman
# 11  A Patriot's History of the United States: From...   Larry Schweikart
# 12                            A Stolen Life: A Memoir      Jaycee Dugard
# 13                   A Wrinkle in Time (Time Quintet)  Madeleine L'Engle
# 14  Act Like a Lady, Think Like a Man: What Men Re...       Steve Harvey
#
#     User Rating  Reviews  Year
# 10          4.6    23848  2017
# 11          4.6      460  2010
# 12          4.6     4149  2011
# 13          4.5     5153  2018
# 14          4.6     5013  2009

# %% [markdown]
# # ADD columns

# %%
books.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Year
# 0                  JJ Smith          4.7    17350  2016
# 1              Stephen King          4.6     2052  2011
# 2        Jordan B. Peterson          4.7    18979  2018
# 3             George Orwell          4.7    21424  2017
# 4  National Geographic Kids          4.8     7665  2019

# %%
books['New_colum'] = np.nan #Se crea una nueva columna dentro del dataframe
books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Year  New_colum
# 0                    JJ Smith          4.7    17350  2016        NaN
# 1                Stephen King          4.6     2052  2011        NaN
# 2          Jordan B. Peterson          4.7    18979  2018        NaN
# ...

# %%
books.shape[0]
# Out:
# 550

# %%
data = np.arange(0, books.shape[0])

# %%
books['Rango'] = data #Si se quieren agregar valores asi se debe tener la misma longitud de las filas.

# %%
books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Year  New_colum  Rango
# 0                    JJ Smith          4.7    17350  2016        NaN      0
# 1                Stephen King          4.6     2052  2011        NaN      1
# ...

# %% [markdown]
# # ADD Rows

# %%
books.append(books) #indexa datos al final del dataframe
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Year  New_colum  Rango
# 0                    JJ Smith          4.7    17350  2016        NaN      0
# 1                Stephen King          4.6     2052  2011        NaN      1
# ...
